# %%
from skimage import data, morphology
import matplotlib.pyplot as plt 
import numpy as np

# Load an image (example using a horse image from skimage)
image = 'Region 1.png' 
#image = morphology.invert(image)  # Invert the image for better skeletonization 

binary = np.array(image) > 0

# Generate the skeleton
skeleton = morphology.skeletonize(image)

# Visualize the results
fig, axes = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(image, cmap='gray')
ax[0].set_title('Original Image')
ax[1].imshow(skeleton, cmap='gray')
ax[1].set_title('Skeleton')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random
from skimage import morphology

# %%
# Load the image
image_path0 = 'Region 1.png' 
image0 = cv2.imread(image_path0)
image_path = 'Region 1.tif' 
image = cv2.imread(image_path)
image_path2 = 'slice.tif' 
image2 = cv2.imread(image_path2)

# %%
binary = np.array(image0) > 0
skeleton = morphology.skeletonize(binary)

# %%
skeleton = morphology.skeletonize(image0)

# %%
np.sum(skeleton==0)
# Out:
# 2482941

# %%
image0 = 255 - image0

# %%
plt.imshow(image0)

# %%
skeleton = morphology.skeletonize(image0)

# %%
plt.imshow(skeleton)

# %%
y = np.where(skeleton)

# %%
np.where(skeleton)
# Out:
# (array([  63,   64,   64, ..., 1405, 1405, 1405], dtype=int64),
#  array([318, 317, 319, ..., 163, 164, 165], dtype=int64),
#  array([1, 1, 1, ..., 1, 1, 1], dtype=int64))
