# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random
from skimage import morphology
# Out:
# C:\Users\akl0407\Anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# Load the image
image_path0 = 'Region 1.png' 
image0 = cv2.imread(image_path0)

# %%
# Load the image
image_path1 = 'Region 1.tif' 
image1 = cv2.imread(image_path1)

# %%
image_path2 = 'slice.tif' 
image2 = cv2.imread(image_path2)

# %%
image1.shape
# Out:
# (5668, 2331, 3)

# %%
image0.shape
# Out:
# (5668, 2331, 3)

# %%
plt.imshow(image1)

# %%
plt.imshow(image0)

# %%
image0.shape
# Out:
# (5668, 2331, 3)

# %%
image2.shape
# Out:
# (5687, 2331, 3)

# %%
plt.imshow(image2)
